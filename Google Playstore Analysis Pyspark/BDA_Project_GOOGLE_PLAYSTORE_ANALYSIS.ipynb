# %% [markdown]
# <h3>1. Importing Necessary Libraries</h3>

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField,StringType,IntegerType
from pyspark.sql.functions import*

# %% [markdown]
# <h3>2. Creating a Dataframe</h3>

# %%
spark = SparkSession.builder.appName('googleplaystoreanalysis').getOrCreate()
df=spark.read.load('googleplaystore.csv',format='csv',sep=',',header='true',escape='"',inferschema='true')
df.show(n=5, truncate=False)
# Out:
# +--------------------------------------------------+--------------+------+-------+----+-----------+----+-----+--------------+-------------------------+----------------+------------------+------------+
# |App                                               |Category      |Rating|Reviews|Size|Installs   |Type|Price|Content Rating|Genres                   |Last Updated    |Current Ver       |Android Ver |
# +--------------------------------------------------+--------------+------+-------+----+-----------+----+-----+--------------+-------------------------+----------------+------------------+------------+
# |Photo Editor & Candy Camera & Grid & ScrapBook    |ART_AND_DESIGN|4.1   |159    |19M |10,000+    |Free|0    |Everyone      |Art & Design             |January 7, 2018 |1.0.0             |4.0.3 and up|
# |Coloring book moana                               |ART_AND_DESIGN|3.9   |967    |14M |500,000+   |Free|0    |Everyone      |Art & Design;Pretend Play|January 15, 2018|2.0.0             |4.0.3 and up|
# |U Launcher Lite – FREE Live Cool Themes, Hide Apps|ART_AND_DESIGN|4.7   |87510  |8.7M|5,000,000+ |Free|0    |Everyone      |Art & Design             |August 1, 2018  |1.2.4             |4.0.3 and up|
# |Sketch - Draw & Paint                             |ART_AND_DESIGN|4.5   |215644 |25M |50,000,000+|Free|0    |Teen          |Art & Design             |June 8, 2018    |Varies with device|4.2 and up  |
# |Pixel Draw - Number Art Coloring Book             |ART_AND_DESIGN|4.3   |967    |2.8M|100,000+   |Free|0    |Everyone      |Art & Design;Creativity  |June 20, 2018   |1.1               |4.4 and up  |
# +--------------------------------------------------+--------------+------+-------+----+-----------+----+-----+--------------+-------------------------+----------------+------------------+------------+
# only showing top 5 rows

# %%
df.take(1)
# Out:
# [Row(App='Photo Editor & Candy Camera & Grid & ScrapBook', Category='ART_AND_DESIGN', Rating=4.1, Reviews='159', Size='19M', Installs='10,000+', Type='Free', Price='0', Content Rating='Everyone', Genres='Art & Design', Last Updated='January 7, 2018', Current Ver='1.0.0', Android Ver='4.0.3 and up')]

# %% [markdown]
# <h4>2.1. Count number of rows in DataFrame</h4>

# %%
df.count()
# Out:
# 10841

# %% [markdown]
# <h4>2.2. Printing Schema</h4>

# %%
df.printSchema()
# Out:
# root
#  |-- App: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Rating: double (nullable = true)
#  |-- Reviews: string (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- Installs: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: string (nullable = true)
#  |-- Content Rating: string (nullable = true)
#  |-- Genres: string (nullable = true)
#  |-- Last Updated: string (nullable = true)
#  |-- Current Ver: string (nullable = true)
#  |-- Android Ver: string (nullable = true)

# %% [markdown]
# <h3>3. Data Cleaning and PreProcessing</h3>

# %% [markdown]
# <h4>3.1. Dropping unecessary columns</h4>
# <p>Removing the columns "Size", "Content Rating", "Last Updated", "Current Ver", and "Android Ver" from the DataFrame which are not required </p>

# %%
df=df.drop("Size","Content Rating","Last Updated","Current Ver","Android Ver")
df.show(5)
# Out:
# +--------------------+--------------+------+-------+-----------+----+-----+--------------------+
# |                 App|      Category|Rating|Reviews|   Installs|Type|Price|              Genres|
# +--------------------+--------------+------+-------+-----------+----+-----+--------------------+
# |Photo Editor & Ca...|ART_AND_DESIGN|   4.1|    159|    10,000+|Free|    0|        Art & Design|
# | Coloring book moana|ART_AND_DESIGN|   3.9|    967|   500,000+|Free|    0|Art & Design;Pret...|
# |U Launcher Lite –...|ART_AND_DESIGN|   4.7|  87510| 5,000,000+|Free|    0|        Art & Design|
# |Sketch - Draw & P...|ART_AND_DESIGN|   4.5| 215644|50,000,000+|Free|    0|        Art & Design|
# |Pixel Draw - Numb...|ART_AND_DESIGN|   4.3|    967|   100,000+|Free|    0|Art & Design;Crea...|
# +--------------------+--------------+------+-------+-----------+----+-----+--------------------+
# only showing top 5 rows

# %%
df=df.na.drop(subset=['Rating'])
df=df.filter(df['Rating']<=5.0)

# %%
df.printSchema()
# Out:
# root
#  |-- App: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Rating: double (nullable = true)
#  |-- Reviews: string (nullable = true)
#  |-- Installs: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: string (nullable = true)
#  |-- Genres: string (nullable = true)

# %% [markdown]
# <h4>3.2. Normalization</h4>
# <ul>
#     <li>Converting "Reviews" column to integer type</li>
#     <li>Removing non-numeric characters from the "Installs" column and converts it to integer type</li>
#     <li>Removing the dollar sign from the "Price" column and converts it to integer type</li>
# </ul>

# %%
from pyspark.sql.functions import regexp_replace,col
df=df.withColumn("Reviews",col("Reviews").cast(IntegerType()))\
.withColumn("Installs",regexp_replace(col("Installs"),"[^0-9]",""))\
.withColumn("Installs",col("Installs").cast(IntegerType()))\
            .withColumn("Price",regexp_replace(col("price"),"[$]",""))\
              .withColumn("Price",col("price").cast(IntegerType()))

# %%
df.show(5)
# Out:
# +--------------------+--------------+------+-------+--------+----+-----+--------------------+
# |                 App|      Category|Rating|Reviews|Installs|Type|Price|              Genres|
# +--------------------+--------------+------+-------+--------+----+-----+--------------------+
# |Photo Editor & Ca...|ART_AND_DESIGN|   4.1|    159|   10000|Free|    0|        Art & Design|
# | Coloring book moana|ART_AND_DESIGN|   3.9|    967|  500000|Free|    0|Art & Design;Pret...|
# |U Launcher Lite –...|ART_AND_DESIGN|   4.7|  87510| 5000000|Free|    0|        Art & Design|
# |Sketch - Draw & P...|ART_AND_DESIGN|   4.5| 215644|50000000|Free|    0|        Art & Design|
# |Pixel Draw - Numb...|ART_AND_DESIGN|   4.3|    967|  100000|Free|    0|Art & Design;Crea...|
# +--------------------+--------------+------+-------+--------+----+-----+--------------------+
# only showing top 5 rows

# %% [markdown]
# <h3>4. Creating View and using SQL for displaying the Dataframe</h3>

# %%
df.createOrReplaceTempView("apps")

# %%
spark.sql('''
SELECT * FROM apps
''').show(5)
# Out:
# +--------------------+--------------+------+-------+--------+----+-----+--------------------+
# |                 App|      Category|Rating|Reviews|Installs|Type|Price|              Genres|
# +--------------------+--------------+------+-------+--------+----+-----+--------------------+
# |Photo Editor & Ca...|ART_AND_DESIGN|   4.1|    159|   10000|Free|    0|        Art & Design|
# | Coloring book moana|ART_AND_DESIGN|   3.9|    967|  500000|Free|    0|Art & Design;Pret...|
# |U Launcher Lite –...|ART_AND_DESIGN|   4.7|  87510| 5000000|Free|    0|        Art & Design|
# |Sketch - Draw & P...|ART_AND_DESIGN|   4.5| 215644|50000000|Free|    0|        Art & Design|
# |Pixel Draw - Numb...|ART_AND_DESIGN|   4.3|    967|  100000|Free|    0|Art & Design;Crea...|
# +--------------------+--------------+------+-------+--------+----+-----+--------------------+
# only showing top 5 rows

# %% [markdown]
# <h3>5. Data Analysis</h3>

# %% [markdown]
# <h4>5.1. Top apps by Number of Reviews</h4>

# %%
spark.sql('''
SELECT App,SUM(Reviews) as TotalReviews
FROM apps
GROUP BY App
ORDER BY TotalReviews DESC
''').show(10)
# Out:
# +--------------------+------------+
# |                 App|TotalReviews|
# +--------------------+------------+
# |           Instagram|   266241989|
# |  WhatsApp Messenger|   207348304|
# |      Clash of Clans|   179558781|
# |Messenger – Text ...|   169932272|
# |      Subway Surfers|   166331958|
# |    Candy Crush Saga|   156993136|
# |            Facebook|   156286514|
# |         8 Ball Pool|    99386198|
# |        Clash Royale|    92530298|
# |            Snapchat|    68045010|
# +--------------------+------------+
# only showing top 10 rows

# %% [markdown]
# <h4>5.2. Top apps by installation and classifying whether paid or free</h4>

# %%
spark.sql('''
SELECT App,SUM(Installs) as TotalInstalls
FROM apps
GROUP BY App
ORDER BY TotalInstalls DESC
''').show(10)
# Out:
# +------------------+-------------+
# |               App|TotalInstalls|
# +------------------+-------------+
# |    Subway Surfers|   6000000000|
# |         Instagram|   4000000000|
# |          Hangouts|   4000000000|
# |      Google Drive|   4000000000|
# |       Google News|   4000000000|
# |     Google Photos|   4000000000|
# |  Candy Crush Saga|   3500000000|
# |             Gmail|   3000000000|
# |WhatsApp Messenger|   3000000000|
# |      Temple Run 2|   3000000000|
# +------------------+-------------+
# only showing top 10 rows

# %%
spark.sql('''
SELECT App,Type,SUM(Installs) as TotalInstalls
FROM apps
GROUP BY App,Type
ORDER BY TotalInstalls DESC
''').show(10)
# Out:
# +------------------+----+-------------+
# |               App|Type|TotalInstalls|
# +------------------+----+-------------+
# |    Subway Surfers|Free|   6000000000|
# |         Instagram|Free|   4000000000|
# |      Google Drive|Free|   4000000000|
# |          Hangouts|Free|   4000000000|
# |     Google Photos|Free|   4000000000|
# |       Google News|Free|   4000000000|
# |  Candy Crush Saga|Free|   3500000000|
# |WhatsApp Messenger|Free|   3000000000|
# |             Gmail|Free|   3000000000|
# |      Temple Run 2|Free|   3000000000|
# +------------------+----+-------------+
# only showing top 10 rows

# %% [markdown]
# <h4>5.3. Top Categories by Installations</h4>

# %%
spark.sql('''
SELECT Category,SUM(Installs) as TotalInstalls
FROM apps
GROUP BY Category
ORDER BY TotalInstalls DESC
''').show(10)
# Out:
# +------------------+-------------+
# |          Category|TotalInstalls|
# +------------------+-------------+
# |              GAME|  35085862717|
# |     COMMUNICATION|  32647241530|
# |      PRODUCTIVITY|  14176070180|
# |            SOCIAL|  14069841475|
# |             TOOLS|  11450724500|
# |            FAMILY|  10257701590|
# |       PHOTOGRAPHY|  10088243130|
# |NEWS_AND_MAGAZINES|   7496210650|
# |  TRAVEL_AND_LOCAL|   6868859300|
# |     VIDEO_PLAYERS|   6221897200|
# +------------------+-------------+
# only showing top 10 rows

# %% [markdown]
# <h4>5.4. Top apps with Highest Prices</h4>

# %%
spark.sql('''
SELECT App,SUM(Price) as TotalCost
FROM apps
WHERE Type='Paid'
GROUP BY App
ORDER BY TotalCost DESC
''').show(10)
# Out:
# +--------------------+---------+
# |                 App|TotalCost|
# +--------------------+---------+
# |I'm Rich - Trump ...|      400|
# |      I am Rich Plus|      399|
# |  I AM RICH PRO PLUS|      399|
# |   I Am Rich Premium|      399|
# |most expensive ap...|      399|
# |          I am Rich!|      399|
# |       I Am Rich Pro|      399|
# |  I am rich(premium)|      399|
# |           I am Rich|      399|
# |         💎 I'm rich|      399|
# +--------------------+---------+
# only showing top 10 rows

# %% [markdown]
# <h4>5.5 Highest rated apps</h4>

# %%
spark.sql('''
SELECT App,Rating
FROM apps
ORDER BY Rating DESC
''').show(10000)
# Out:
# +----------------------------------+------+
# |                               App|Rating|
# +----------------------------------+------+
# |              Hojiboy Tojiboyev...|   5.0|
# |              American Girls Mo...|   5.0|
# |                      Awake Dating|   5.0|
# |              Spine- The dating...|   5.0|
# |              Girls Live Talk -...|   5.0|
# |              Online Girls Chat...|   5.0|
# |              Speeding Joyride ...|   5.0|
# |                  SUMMER SONIC app|   5.0|
# |                        Prosperity|   5.0|
# |              Mindvalley U Tall...|   5.0|
# |                      Eternal life|   5.0|
# |              Super Hearing Sec...|   5.0|
# |                    FHR 5-Tier 2.0|   5.0|
# |                      Sway Medical|   5.0|
# |                    Labs on Demand|   5.0|
# |              Dermatology Atlas...|   5.0|
# |                   Tablet Reminder|   5.0|
# |                  Galaxies of Hope|   5.0|
# |               KBA-EZ Health Guide|   5.0|
# |                      FoothillsVet|   5.0|
# |                     PrimeDelivery|   5.0|
# |                   You're an Anime|   5.0|
# |              Anatomy & Physiol...|   5.0|
# |              NCLEX Multi-topic...|   5.0|
# |              Basics of Orthopa...|   5.0|
# |                 Clinic Doctor EHr|   5.0|
# |                      Sway Medical|   5.0|
# |              420 BZ Budeze Del...|   5.0|
# |              BP Journal - Bloo...|   5.0|
# |                          Zen Leaf|   5.0|
# |                      ADS-B Driver|   5.0|
# |                   P-Home for KLWP|   5.0|
# |              Android P Style I...|   5.0|
# |              R Programing Offl...|   5.0|
# |              Easy Hotspot Ad Free|   5.0|
# |              Tafsiir Quraan MP...|   5.0|
# |              Lakeside AG Moultrie|   5.0|
# |                  Eternal Light AG|   5.0|
# |              Ag Valley Coopera...|   5.0|
# |                      Chenoweth AH|   5.0|
# |                  Arrowhead AH App|   5.0|
# |                      Kimbrough AH|   5.0|
# |              AI Today : Artifi...|   5.0|
# |                            AJ Cam|   5.0|
# |              Hey AJ! It's Satu...|   5.0|
# |              Selfie With Champ...|   5.0|
# |                        AJ RETAILS|   5.0|
# |              Hey AJ! It's Bedt...|   5.0|
# |                 AJ Men's Grooming|   5.0|
# |              AJ Gray Dark Icon...|   5.0|
# |                 AJ Blue Icon Pack|   5.0|
# |              AJ Rafael Music L...|   5.0|
# |                         AP® Guide|   5.0|
# |              meStudying: AP En...|   5.0|
# |              AP Art History Fl...|   5.0|
# |                     AQ Ria Retail|   5.0|
# |              Accounting Quiz (...|   5.0|
# |               Wowkwis aq Ka'qaquj|   5.0|
# |              Jobs in Canada - ...|   5.0|
# |              Tozer Devotional ...|   5.0|
# |              Food-Aw - Order F...|   5.0|
# |                  Axe Champs! Wars|   5.0|
# |              Flippy Axe : Flip...|   5.0|
# |                    A-Y Collection|   5.0|
# |              Quran Khmer Offli...|   5.0|
# |                          Ra Ga Ba|   5.0|
# |                      BC MVA Fines|   5.0|
# |              Railroad Radio Va...|   5.0|
# |                     iCard BD Plus|   5.0|
# |                    Exam Result BD|   5.0|
# |                        Helping BD|   5.0|
# |                       Movement BE|   5.0|
# |              ReactNative BG Ge...|   5.0|
# |                          BG Guide|   5.0|
# |                  Bh Public School|   5.0|
# |                        Barbers.BH|   5.0|
# |                           BI News|   5.0|
# |                     Propel BI APP|   5.0|
# |                            BI APP|   5.0|
# |              HON. B.J. ACS COL...|   5.0|
# |                          BJ Foods|   5.0|
# |               Read it easy for BK|   5.0|
# |                   BK Video Status|   5.0|
# |              BK Formula Calcul...|   5.0|
# |                 Dr Bk Sachin bhai|   5.0|
# |              BK Arogyam Task T...|   5.0|
# |                      Bk Usha behn|   5.0|
# |                       BK Gold App|   5.0|
# |                BL Flowers Digital|   5.0|
# |                   BM SPM Practice|   5.0|
# |              BM Physiotherapy ...|   5.0|
# |                     BM speed test|   5.0|
# |              BP Journal - Bloo...|   5.0|
# |                       BP Log lite|   5.0|
# |                             MI-BP|   5.0|
# |                 Bar-B-Q Rib House|   5.0|
# |                  Brick Breaker BR|   5.0|
# |              COMSATS BOOK STOR...|   5.0|
# |                         BS-Mobile|   5.0|
# |                   Wifi BT Scanner|   5.0|
# |                         Jabbla BT|   5.0|
# |                          BU Study|   5.0|
# |              Barisal Universit...|   5.0|
# |              Catholic La Bu Zo...|   5.0|
# |                    BV Mobile Apps|   5.0|
# |                                BV|   5.0|
# |               BV Sridhara Maharaj|   5.0|
# |              Bacterial vaginos...|   5.0|
# |              BxPort - Bitcoin ...|   5.0|
# |              420 BZ Budeze Del...|   5.0|
# |                       CA Speakers|   5.0|
# |                            CB Fit|   5.0|
# |                   CB VIDEO VISION|   5.0|
# |              C B Patel Health ...|   5.0|
# |                           CB News|   5.0|
# |                       CB Register|   5.0|
# |                        Cb browser|   5.0|
# |                         CB Heroes|   5.0|
# |                    CD CHOICE TUBE|   5.0|
# |              Yazdani Cd Center...|   5.0|
# |                          CE Smart|   5.0|
# |              TI-84 CE Graphing...|   5.0|
# |                         MCQ CE IT|   5.0|
# |                           CF Life|   5.0|
# |                          Unity CF|   5.0|
# |                Overcomers CF - GA|   5.0|
# |                                CF|   5.0|
# |                     CF Townsville|   5.0|
# |                         CG Prints|   5.0|
# |                             CG FM|   5.0|
# |               CG - Chemistry free|   5.0|
# |                           CG Jobs|   5.0|
# |              Startupticker.ch ...|   5.0|
# |              CI 174 Gray Icon ...|   5.0|
# |              Trovami se ci riesci|   5.0|
# |              Nur təfsiri 1-ci ...|   5.0|
# |                    CJ Gospel Hour|   5.0|
# |              CJ'S TIRE AND AUT...|   5.0|
# |                     The CJ Rubric|   5.0|
# |                  CJ's Coffee Cafe|   5.0|
# |              Sir C J New Prima...|   5.0|
# |                    CJ the REALTOR|   5.0|
# |                            211:CK|   5.0|
# |              USMLE Step 2 CK F...|   5.0|
# |                CK Employee Portal|   5.0|
# |                        Tic Tac CK|   5.0|
# |                           CL REPL|   5.0|
# |              CL Keyboard - Mya...|   5.0|
# |                       CL Notifier|   5.0|
# |                          Color CL|   5.0|
# |                       CL Strength|   5.0|
# |                       CN Resident|   5.0|
# |                      Foothills CP|   5.0|
# |                  CP Installer App|   5.0|
# |                         CP Trivia|   5.0|
# |                           CQ ESPM|   5.0|
# |                         CricQuick|   5.0|
# |                           iReadMe|   5.0|
# |               Cr Aviation Academy|   5.0|
# |              CR Tracker for Ch...|   5.0|
# |              CS & IT Interview...|   5.0|
# |              CT Brain Interpre...|   5.0|
# |                 CT Cervical Spine|   5.0|
# |              CARDIAC CT TECHNIQUE|   5.0|
# |              Dine In CT - Food...|   5.0|
# |                       CT Checkout|   5.0|
# |                      Morse Player|   5.0|
# |              30WPM Amateur ham...|   5.0|
# |                        Oración CX|   5.0|
# |              cx advance call b...|   5.0|
# |              NOMISMA.com.cy by...|   5.0|
# |              Cy-Fair VFD EMS P...|   5.0|
# |              Cy-Fair Christian...|   5.0|
# |                           CZ-Help|   5.0|
# |                         CZ Kompas|   5.0|
# |                           DB HOME|   5.0|
# |                        DB Pickles|   5.0|
# |              Superheroes, Marv...|   5.0|
# |              DC N COMPANY ENTE...|   5.0|
# |                            DC-014|   5.0|
# |               AC DC Power Monitor|   5.0|
# |              The Divine Femini...|   5.0|
# |                     DF Glue Board|   5.0|
# |                            DG-App|   5.0|
# |              Free coupons and ...|   5.0|
# |              DG OFF - 100% Fre...|   5.0|
# |                             DG TV|   5.0|
# |                            DH-UFO|   5.0|
# |                      D-H Pharmacy|   5.0|
# |               PK and DK Audio App|   5.0|
# |                  DL Image Manager|   5.0|
# |              DM Buddy » Learn ...|   5.0|
# |              Disciple Maker’s ...|   5.0|
# |                           DN Blog|   5.0|
# |                       DN Employee|   5.0|
# |                    DN Calculators|   5.0|
# |                           WPBS-DT|   5.0|
# |                      DT CLOTHINGS|   5.0|
# |               Dt. Jyothi Srinivas|   5.0|
# |              Spring flowers th...|   5.0|
# |                         DV ASSIST|   5.0|
# |                          DV Youth|   5.0|
# |                       DW Security|   5.0|
# |                          DW Timer|   5.0|
# |              RETRO Shocked DW-...|   5.0|
# |                     Chronolink DX|   5.0|
# |              Santa's Monster S...|   5.0|
# |              Cloud DX Connecte...|   5.0|
# |                           DYPSOET|   5.0|
# |                           chat dz|   5.0|
# |                           i am EB|   5.0|
# |                        EB Scanner|   5.0|
# |              UP EB Bill Paymen...|   5.0|
# |               EB Cash Collections|   5.0|
# |                        EC Calgary|   5.0|
# |                       Victoria EC|   5.0|
# |                         EC SPORTS|   5.0|
# |                    EC Fairgrounds|   5.0|
# |                          EC Mover|   5.0|
# |                         EF Events|   5.0|
# |                          EF Forms|   5.0|
# |                            EF App|   5.0|
# |                        EF Academy|   5.0|
# |                          EG India|   5.0|
# |              Eh Bee Wallpapers HD|   5.0|
# |                           NEMA ei|   5.0|
# |                           ei Calc|   5.0|
# |              Kolkata News:Anan...|   5.0|
# |                      EJ messenger|   5.0|
# |                        Master E.K|   5.0|
# |              EK Bailey Preachi...|   5.0|
# |                    Pyaar Ek Dhoka|   5.0|
# |              Ek Bander Ne Khol...|   5.0|
# |                  Hum Ek Hain 2.02|   5.0|
# |                           Ek Vote|   5.0|
# |              Asha Ek Hope - AL...|   5.0|
# |              Ek Qissa He Quran...|   5.0|
# |              Lyrics of Ek Pahe...|   5.0|
# |              Shabad Gurubani P...|   5.0|
# |                           FAST EO|   5.0|
# |               EP Church Annapolis|   5.0|
# |                          EP Radio|   5.0|
# |                         ER Assist|   5.0|
# |              Dr. ES PV Calculator|   5.0|
# |              ES Billing System...|   5.0|
# |                          ES Solar|   5.0|
# |                      EU Exit poll|   5.0|
# |                         daskal.eu|   5.0|
# |              FA Player Essentials|   5.0|
# |              Noticias FC Barce...|   5.0|
# |                     Story Time FD|   5.0|
# |              FD Calculator (EM...|   5.0|
# |              Comunidad De Fe M...|   5.0|
# |                     Safe Santa Fe|   5.0|
# |                   Santa Fe Thrive|   5.0|
# |                        Ríos de Fe|   5.0|
# |              Jigsaw Volvo FH 1...|   5.0|
# |                         FH School|   5.0|
# |                FK CLASSIC FOR YOU|   5.0|
# |                    FK Dedinje BGD|   5.0|
# |              South Florida AA ...|   5.0|
# |              Trinity Church De...|   5.0|
# |              Beacon Baptist Ju...|   5.0|
# |              Florida Beach Wal...|   5.0|
# |               Florida Wildflowers|   5.0|
# |              Wallpapers FN SCAR H|   5.0|
# |                                FN|   5.0|
# |                          FO Bixby|   5.0|
# |                           Mu.F.O.|   5.0|
# |                 Mad Dash Fo' Cash|   5.0|
# |              GKPB FP Online Ch...|   5.0|
# |                  Monster Ride Pro|   5.0|
# |                   Fr. Daoud Lamei|   5.0|
# |              Fr. Mike Schmitz ...|   5.0|
# |              Tickets SDA 2018 ...|   4.9|
# |              CDL Practice Test...|   4.9|
# |              DMV Permit Practi...|   4.9|
# |              Tickets + PDA 201...|   4.9|
# |              ipsy: Makeup, Bea...|   4.9|
# |              eBoox new: Reader...|   4.9|
# |                    FREE LIVE TALK|   4.9|
# |              Learn Japanese, K...|   4.9|
# |               Sago Mini Hat Maker|   4.9|
# |                Mummatikabalkuragi|   4.9|
# |              Lose Belly Fat in...|   4.9|
# |              Six Pack in 30 Da...|   4.9|
# |              StrongLifts 5x5 W...|   4.9|
# |              Down Dog: Great Y...|   4.9|
# |                The Room: Old Sins|   4.9|
# |                    Period Tracker|   4.9|
# |                           VetCode|   4.9|
# |                 Pediatric Nursing|   4.9|
# |              White Noise for Baby|   4.9|
# |              Hungry Hearts Din...|   4.9|
# |                      MHD F-Series|   4.9|
# |                 H*nest Meditation|   4.9|
# |              BTS j-hope LINE L...|   4.9|
# |                   K-Otic Universe|   4.9|
# |              EXO-L Amino for E...|   4.9|
# |                                M+|   4.9|
# |              Six Pack in 30 Da...|   4.9|
# |              Solitaire: Decked...|   4.9|
# |                     AK Lodi Films|   4.9|
# |              AO/OTA Fracture C...|   4.9|
# |                         Sufara.ba|   4.9|
# |              Tour BD (Bahir Da...|   4.9|
# |              BD Internet Packa...|   4.9|
# |              Be My Eyes - Help...|   4.9|
# |                  BG Future School|   4.9|
# |                 Sisense Mobile BI|   4.9|
# |              Business Intellig...|   4.9|
# |              Official Madhuban...|   4.9|
# |                           BL Taxi|   4.9|
# |               Business Mitra (BM)|   4.9|
# |                    BatControl Pro|   4.9|
# |              Borneo Bible, BM ...|   4.9|
# |                       BM Pharmacy|   4.9|
# |                         Word Hunt|   4.9|
# |                        Br Browser|   4.9|
# |                          Br Shafi|   4.9|
# |                         BT Church|   4.9|
# |              PixPanda - Color ...|   4.9|
# |                          FAV KWGT|   4.9|
# |              Legit Check App b...|   4.9|
# |              Aquarium Co-Op Po...|   4.9|
# |                  Doctor Finder CY|   4.9|
# |                      Wallpaper.cz|   4.9|
# |                   DC Comics Amino|   4.9|
# |                  DF-Server Mobile|   4.9|
# |              Diabetes mellitus...|   4.9|
# |              DQSalmaan - A fan...|   4.9|
# |                                DS|   4.9|
# |                    News: DW Hausa|   4.9|
# |                          DW Audio|   4.9|
# |                 KPS CHAUHAN DY/DX|   4.9|
# |                    Tuberculose Dz|   4.9|
# |                            EC Tax|   4.9|
# |              Aaj Bangla: ei sa...|   4.9|
# |                          Ek Onkar|   4.9|
# |                   Duaa Ek Ibaadat|   4.9|
# |                  Ek Onkar Mantras|   4.9|
# |              Alex Fuel Calcula...|   4.9|
# |              Sai Baba - Sabka ...|   4.9|
# |              Sanu Ek Pal Chain...|   4.9|
# |                        JW Library|   4.9|
# |                     EP Horlogerie|   4.9|
# |              Égalité et Réconc...|   4.9|
# |                     EV Calculator|   4.9|
# |                   Eddsworld Amino|   4.9|
# |                      EY Forensics|   4.9|
# |                          FC Porto|   4.9|
# |                        Burnley FC|   4.9|
# |               Las Vegas Lights FC|   4.9|
# |              FD VR Music Video...|   4.9|
# |                      FG On-The-Go|   4.9|
# |                            FH App|   4.9|
# |                    FK Željezničar|   4.9|
# |                  FK Crvena zvezda|   4.9|
# |               FK Željezničar Izzy|   4.9|
# |                         Canvas FL|   4.9|
# |               Fr Ignacio Outreach|   4.9|
# |              Harley Quinn wall...|   4.8|
# |              Fines of the Stat...|   4.8|
# |                            PDD-UA|   4.8|
# |              Tickets SDA 2019 ...|   4.8|
# |              Prom MakeUp Tutorial|   4.8|
# |              Free Books - Spir...|   4.8|
# |              ReadEra – free eb...|   4.8|
# |              Job Search by Zip...|   4.8|
# |              Tiny Scanner Pro:...|   4.8|
# |              Tiny Scanner Pro:...|   4.8|
# |              Unicorn Pokez - C...|   4.8|
# |                  Should I Answer?|   4.8|
# |              Live Girls Talk -...|   4.8|
# |              Girls Live Chat -...|   4.8|
# |              FREE VIDEO CHAT -...|   4.8|
# |              Live Chat - Free ...|   4.8|
# |              Live Girls Talk -...|   4.8|
# |              Girls Live Chat -...|   4.8|
# |                 Online Girls Chat|   4.8|
# |              English Grammar Test|   4.8|
# |              SoloLearn: Learn ...|   4.8|
# |                Emmabodafestivalen|   4.8|
# |              Arab Halls - For ...|   4.8|
# |              Even - organize y...|   4.8|
# |              SarashpazPapion (...|   4.8|
# |              Home Workout - No...|   4.8|
# |              Pedometer - Step ...|   4.8|
# |              Lose Weight in 30...|   4.8|
# |              Sportractive GPS ...|   4.8|
# |              30 Day Fitness Ch...|   4.8|
# |              Home Workout for ...|   4.8|
# |                      Sleep Sounds|   4.8|
# |              Relax Melodies P:...|   4.8|
# |              Period Tracker - ...|   4.8|
# |              Period Tracker Cl...|   4.8|
# |              Prana Breath: Cal...|   4.8|
# |              Viva Decora - Dec...|   4.8|
# |                     Nature Sounds|   4.8|
# |                        Wordscapes|   4.8|
# |                        Wordscapes|   4.8|
# |                        Wordscapes|   4.8|
# |              Cash, Inc. Money ...|   4.8|
# |                        Wordscapes|   4.8|
# |              No. Color - Color...|   4.8|
# |              Fuzzy Seasons: An...|   4.8|
# |                        Pino chess|   4.8|
# |                         Hactar Go|   4.8|
# |              World Racers fami...|   4.8|
# |              Journal Club: Med...|   4.8|
# |              Hospitalist Handbook|   4.8|
# |              GoodRx Drug Price...|   4.8|
# |              Ovia Pregnancy Tr...|   4.8|
# |              Pregnancy Week By...|   4.8|
# |              Ovia Fertility Tr...|   4.8|
# |              Pregnancy Calcula...|   4.8|
# |              VitusVet: Pet Hea...|   4.8|
# |              Journal Club: Med...|   4.8|
# |              Hospitalist Handbook|   4.8|
# |              Ovia Fertility Tr...|   4.8|
# |              Amino: Communitie...|   4.8|
# |              FreePrints – Free...|   4.8|
# |                     The 5th Stand|   4.8|
# |              Live Tennis Ranki...|   4.8|
# |              Yoriza Pension - ...|   4.8|
# |                     TravelPirates|   4.8|
# |              Calculator with P...|   4.8|
# |                 OnePlus Icon Pack|   4.8|
# |              How do I take car...|   4.8|
# |              The first year of...|   4.8|
# |              Rainbow - Journal...|   4.8|
# |              Classical music f...|   4.8|
# |                  Weather forecast|   4.8|
# |                  Live Weather Pro|   4.8|
# |                  Weather Live Pro|   4.8|
# |              Video Player All ...|   4.8|
# |              GPS Speedometer a...|   4.8|
# |              Find a Way: Addic...|   4.8|
# |              CompTIA Exam Trai...|   4.8|
# |                 Cardi B Wallpaper|   4.8|
# |              Neon Glow C - Ico...|   4.8|
# |                       C Functions|   4.8|
# |                         C Prowess|   4.8|
# |                 C BOOK-C PROGRAMS|   4.8|
# |              DU Recorder – Scr...|   4.8|
# |                          Eternium|   4.8|
# |              K keyboard - Myanmar|   4.8|
# |              KPOP Amino for K-...|   4.8|
# |                            K.MOJI|   4.8|
# |              K-Spapp, the K-Sp...|   4.8|
# |                      Anna.K Tarot|   4.8|
# |                       Drag'n'Boom|   4.8|
# |              Dark Infusion Sub...|   4.8|
# |              Materialistic P W...|   4.8|
# |              Pixel Oreo/P Dark...|   4.8|
# |                      Q Avatar Pro|   4.8|
# |                    R File Manager|   4.8|
# |                     Day R Premium|   4.8|
# |               Shopping List S PRO|   4.8|
# |                      The T Factor|   4.8|
# |              Alarmy (Sleep If ...|   4.8|
# |              BTS V LINE Launch...|   4.8|
# |              BTS V Kim Taehyun...|   4.8|
# |                      IRS W-9 form|   4.8|
# |              X Launcher Pro - ...|   4.8|
# |              PewDiePie's Tuber...|   4.8|
# |              Space Z 🌏 🚀Icon...|   4.8|
# |                  ZArchiver Donate|   4.8|
# |              Abs Workout - Bur...|   4.8|
# |              Abs, Core & Back ...|   4.8|
# |              ABS Workout - Bel...|   4.8|
# |              7 minute abs work...|   4.8|
# |              30 Day AB Challen...|   4.8|
# |              Abs workout - 21 ...|   4.8|
# |                         Pocket AC|   4.8|
# |                    Flud (Ad free)|   4.8|
# |                           Rоhi.af|   4.8|
# |                         AJ Player|   4.8|
# |              AJ Styles HD Wall...|   4.8|
# |                 AJ Gray Icon Pack|   4.8|
# |              Puppy Shooting an...|   4.8|
# |              Al Quran (Tafsir ...|   4.8|
# |                Al Quran Indonesia|   4.8|
# |              Quran for All (Al...|   4.8|
# |              Koran Read &MP3 3...|   4.8|
# |              SofaScore Live Score|   4.8|
# |              AP World History:...|   4.8|
# |                Undertale AU Amino|   4.8|
# |              Video Player All ...|   4.8|
# |                     Aw Restaurant|   4.8|
# |                The Pursuit of God|   4.8|
# |              INTERACTIVE CALCU...|   4.8|
# |                           AY Sing|   4.8|
# |                       Catalyst AZ|   4.8|
# |                   Az Video Status|   4.8|
# |                  Learn alif ba ta|   4.8|
# |              Elif Ba - Learn T...|   4.8|
# |              Town of Princeton...|   4.8|
# |              BD Briight: Your ...|   4.8|
# |                      BD Fishpedia|   4.8|
# |                     BD Attendance|   4.8|
# |              Best Browser BD s...|   4.8|
# |                       Be Stronger|   4.8|
# |                       BG Products|   4.8|
# |                   BG+Phone Backup|   4.8|
# |              BGKontakti Vienna...|   4.8|
# |              BG Metro - Red vo...|   4.8|
# |                         Revita.bg|   4.8|
# |                        BH Patrole|   4.8|
# |              BH Challenge - Mu...|   4.8|
# |                      The Daily BJ|   4.8|
# |              BK Murli Offline ...|   4.8|
# |              Baba Yaad Hai?(BK's)|   4.8|
# |              BK murli today (M...|   4.8|
# |                         WebComics|   4.8|
# |              Chess of Blades (...|   4.8|
# |                      Mobilight-BM|   4.8|
# |                   Bar-B-Q Recipes|   4.8|
# |                       QR Code Pro|   4.8|
# |                  Dr. B.R.Ambedkar|   4.8|
# |              Vlogger Go Viral ...|   4.8|
# |              BT Find Address f...|   4.8|
# |                          Aegis BT|   4.8|
# |                 sustainability@BU|   4.8|
# |                   Kristian Hla Bu|   4.8|
# |                             BW-Go|   4.8|
# |              Fantasy theme dar...|   4.8|
# |              Bitcoin & Cryptoc...|   4.8|
# |              Pixyfy: coloring ...|   4.8|
# |                   BZ Reminder PRO|   4.8|
# |              Park Limousine: R...|   4.8|
# |                  CA Speakers Free|   4.8|
# |              Citizens Bank - C...|   4.8|
# |              Magana Jari ce Li...|   4.8|
# |              Sermon on Proverb...|   4.8|
# |                        Pixxy KWGT|   4.8|
# |              CI Capital - Dynamic|   4.8|
# |              cm to inches | ce...|   4.8|
# |              ClanPlay: Communi...|   4.8|
# |              Cp Calculator for...|   4.8|
# |                          Calcy IV|   4.8|
# |              CS Interview Ques...|   4.8|
# |              DU CS Lectures - ...|   4.8|
# |              CT-ART 4.0 (Chess...|   4.8|
# |              Radiological Anat...|   4.8|
# |              Firefighters Firs...|   4.8|
# |              2 Amateur ham rad...|   4.8|
# |              CW Beacon for Ham...|   4.8|
# |              Morse Machine for...|   4.8|
# |                            go41cx|   4.8|
# |                         Cy-Reader|   4.8|
# |              The House of Da V...|   4.8|
# |              Dan the Man: Acti...|   4.8|
# |              DB for Hustle Castle|   4.8|
# |                        DG Fitness|   4.8|
# |              Stop Smoking - Ea...|   4.8|
# |              Video Downloader ...|   4.8|
# |                                dk|   4.8|
# |                         DK Murali|   4.8|
# |              Faceoff DP Battle...|   4.8|
# |                       DS-Students|   4.8|
# |                            dt Pro|   4.8|
# |              Du Chinese – Mand...|   4.8|
# |              DV 2018 Winners G...|   4.8|
# |                  German Listening|   4.8|
# |                          Human Dx|   4.8|
# |                           EB-Link|   4.8|
# |              TN Patta /Chitta ...|   4.8|
# |                          EF Coach|   4.8|
# |              أحداث وحقائق | خب...|   4.8|
# |              Equestria Amino f...|   4.8|
# |              TeamWard – live h...|   4.8|
# |                        Ek Maratha|   4.8|
# |                           El Falı|   4.8|
# |                        Fernanfloo|   4.8|
# |              File Manager by X...|   4.8|
# |              Anime et Manga Am...|   4.8|
# |              Amino: Communitie...|   4.8|
# |              Home Workout - No...|   4.8|
# |              Barca News - FC B...|   4.8|
# |              My AEK - Official...|   4.8|
# |                     The 5th Stand|   4.8|
# |              FD Calculator | T...|   4.8|
# |                        FE Connect|   4.8|
# |                            FG VOC|   4.8|
# |                      POLARIS 2MFG|   4.8|
# |              Puzzles Volvo FH ...|   4.8|
# |                          FiSwitch|   4.8|
# |              Kernel Manager fo...|   4.8|
# |              FK Crvena Zvezda ...|   4.8|
# |              Gainesville Flori...|   4.8|
# |                   Ninja FN Button|   4.8|
# |                          NFP 2018|   4.8|
# |                 Fr Lupupa Sermons|   4.8|
# |                       Chemin (fr)|   4.8|
# |              U Launcher Lite –...|   4.7|
# |              Kids Paint Free -...|   4.7|
# |              Photo Designer - ...|   4.7|
# |              Superheroes Wallp...|   4.7|
# |              HD Mickey Minnie ...|   4.7|
# |              Colorfit - Drawin...|   4.7|
# |                   I Creative Idea|   4.7|
# |              UNICORN - Color B...|   4.7|
# |              PIP Camera - PIP ...|   4.7|
# |              Canva: Poster, ba...|   4.7|
# |              Hush - Beauty for...|   4.7|
# |              Natural recipes f...|   4.7|
# |              Tie - Always be h...|   4.7|
# |                       Ulta Beauty|   4.7|
# |              Methods of teeth ...|   4.7|
# |              Offline: English ...|   4.7|
# |              NOOK App for NOOK...|   4.7|
# |              eBoox: book reade...|   4.7|
# |              ATI Cargoes and T...|   4.7|
# |              Tiny Scanner - PD...|   4.7|
# |              TurboScan: scan d...|   4.7|
# |              Tiny Scanner - PD...|   4.7|
# |              TurboScan: scan d...|   4.7|
# |              GANMA! - All orig...|   4.7|
# |              Röhrich Werner So...|   4.7|
# |              Dragon Ball Wallp...|   4.7|
# |                    Faustop Sounds|   4.7|
# |              Best Wallpapers B...|   4.7|
# |              Chat Kids - Chat ...|   4.7|
# |              Live Chat - Free ...|   4.7|
# |              Online Chat Girls...|   4.7|
# |              Chat Kids - Chat ...|   4.7|
# |              Girls Online Talk...|   4.7|
# |                   LIVE VIDEO TALK|   4.7|
# |              Free Live Talk-Vi...|   4.7|
# |              Duolingo: Learn L...|   4.7|
# |              English Communica...|   4.7|
# |              Learn English wit...|   4.7|
# |              Learn Spanish - E...|   4.7|
# |              English words app...|   4.7|
# |              English with Ling...|   4.7|
# |              Learn languages, ...|   4.7|
# |                        Learn Java|   4.7|
# |                        Learn HTML|   4.7|
# |                         Learn SQL|   4.7|
# |              Duolingo: Learn L...|   4.7|
# |              Learn languages, ...|   4.7|
# |               Free english course|   4.7|
# |              Duolingo: Learn L...|   4.7|
# |              Learn languages, ...|   4.7|
# |              Learn English wit...|   4.7|
# |              Duolingo: Learn L...|   4.7|
# |              Learn languages, ...|   4.7|
# |              Fuzzy Numbers: Pr...|   4.7|
# |                   Toca Life: City|   4.7|
# |               Toca Life: Hospital|   4.7|
# |              🔥 Football Wallp...|   4.7|
# |                          Wipe out|   4.7|
# |                            Nubank|   4.7|
# |                               IKO|   4.7|
# |                      Credit Karma|   4.7|
# |              WalletHub - Free ...|   4.7|
# |                      Credit Karma|   4.7|
# |              Everlance: Free M...|   4.7|
# |              Associated Credit...|   4.7|
# |                      Easy Recipes|   4.7|
# |                 Delicious Recipes|   4.7|
# |                           Tastely|   4.7|
# |              Pastry & Cooking ...|   4.7|
# |                    Simple Recipes|   4.7|
# |                Domino's Pizza USA|   4.7|
# |              Recipes Pastries ...|   4.7|
# |                Domino's Pizza USA|   4.7|
# |              BeyondMenu Food D...|   4.7|
# |              Step Counter - Pe...|   4.7|
# |              Abs Training-Burn...|   4.7|
# |              Calorie Counter -...|   4.7|
# |              Running Distance ...|   4.7|
# |              Keep Trainer - Wo...|   4.7|
# |              Simple Habit Medi...|   4.7|
# |              Couch to 5K by Ru...|   4.7|
# |                   White Sound Pro|   4.7|
# |              Simple Habit Medi...|   4.7|
# |                   DIY On A Budget|   4.7|
# |                             Ruler|   4.7|
# |                     Call Recorder|   4.7|
# |              Blackpink as if i...|   4.7|
# |              Girls Nancy Ajram...|   4.7|
# |              သိင်္ Astrology -...|   4.7|
# |                         StyleSeat|   4.7|
# |                         StyleSeat|   4.7|
# |                         Solitaire|   4.7|
# |               Bubble Witch 3 Saga|   4.7|
# |                       Word Search|   4.7|
# |                   Zombie Catchers|   4.7|
# |                        Toon Blast|   4.7|
# |                         Toy Blast|   4.7|
# |                       Word Search|   4.7|
# |                        Bowmasters|   4.7|
# |                   Zombie Catchers|   4.7|
# |              Pixel Art: Color ...|   4.7|
# |                        Toon Blast|   4.7|
# |                        Bowmasters|   4.7|
# |                    Piano Tiles 2™|   4.7|
# |                      Woody Puzzle|   4.7|
# |              Color by Number –...|   4.7|
# |                            PLANK!|   4.7|
# |              Cooking Madness -...|   4.7|
# |                 Honkai Impact 3rd|   4.7|
# |              Hustle Castle: Fa...|   4.7|
# |                       Idle Heroes|   4.7|
# |                 Honkai Impact 3rd|   4.7|
# |                        Toon Blast|   4.7|
# |                         Toy Blast|   4.7|
# |                       Word Search|   4.7|
# |                   Zombie Catchers|   4.7|
# |                        Bowmasters|   4.7|
# |              Pixel Art: Color ...|   4.7|
# |                        Bowmasters|   4.7|
# |                   Zombie Catchers|   4.7|
# |              Cover Fire: offli...|   4.7|
# |              CATS: Crash Arena...|   4.7|
# |                       Soul Knight|   4.7|
# |                 Once Upon a Tower|   4.7|
# |                         Solitaire|   4.7|
# |                   Zombie Catchers|   4.7|
# |                  Gems or jewels ?|   4.7|
# |                        Bowmasters|   4.7|
# |              Pixel Art: Color ...|   4.7|
# |              Dog Run - Pet Dog...|   4.7|
# |                   Candy Pop Story|   4.7|
# |              Dog Run - Pet Dog...|   4.7|
# |              Duolingo: Learn L...|   4.7|
# |              Dog Run - Pet Dog...|   4.7|
# |              Ninja Dash - Roni...|   4.7|
# |                     Monica Toy TV|   4.7|
# |              Sworkit Kids - Fi...|   4.7|
# |                   Toca Life: City|   4.7|
# |              Children Educatio...|   4.7|
# |              Lanterns: The Har...|   4.7|
# |              Tsuro - The Game ...|   4.7|
# |              Duolingo: Learn L...|   4.7|
# |              OmniMedix Medical...|   4.7|
# |              Navi Radiography Pro|   4.7|
# |                  Doctor On Demand|   4.7|
# |              My Calendar - Per...|   4.7|
# |              1800 Contacts - L...|   4.7|
# |              Blood Pressure Lo...|   4.7|
# |              Ovia Parenting & ...|   4.7|
# |              Ada - Your Health...|   4.7|
# |              Migraine Buddy - ...|   4.7|
# |                  Teach Me Anatomy|   4.7|
# |              Baritastic - Bari...|   4.7|
# |              Johns Hopkins Gui...|   4.7|
# |              Ada - Your Health...|   4.7|
# |                         IHSS Help|   4.7|
# |              BELONG Beating Ca...|   4.7|
# |                           TelaDoc|   4.7|
# |              1800 Contacts - L...|   4.7|
# |                         The birth|   4.7|
# |              Mercado Libre: Fi...|   4.7|
# |                              Nike|   4.7|
# |              Shopular: Coupons...|   4.7|
# |              Shopular: Coupons...|   4.7|
# |                              ASOS|   4.7|
# |                              ASOS|   4.7|
# |              Moony Lab - Print...|   4.7|
# |              LALALAB prints yo...|   4.7|
# |              Face Filter, Self...|   4.7|
# |              LightX Photo Edit...|   4.7|
# |              Selfie Camera: Be...|   4.7|
# |              Sweet Camera - Se...|   4.7|
# |              Video Editor Musi...|   4.7|
# |              Onefootball - Soc...|   4.7|
# |              FotMob - Live Soc...|   4.7|
# |                  GollerCepte 1903|   4.7|
# |              Lionel Messi Wall...|   4.7|
# |              FotMob - Live Soc...|   4.7|
# |              Booking.com Trave...|   4.7|
# |              Offline Maps & Na...|   4.7|
# |              Booking.com Trave...|   4.7|
# |              Where is my Train...|   4.7|
# |              Booking.com Trave...|   4.7|
# |                        DreamTrips|   4.7|
# |                        Flashlight|   4.7|
# |              Brightest Flashli...|   4.7|
# |              CALCU™ Stylish Ca...|   4.7|
# |                     Evie Launcher|   4.7|
# |                    ZenUI Launcher|   4.7|
# |              Color Call - Call...|   4.7|
# |              Emoji Keyboard - ...|   4.7|
# |              Backgrounds (HD W...|   4.7|
# |                Goku Wallpaper Art|   4.7|
# |              OnePlus Icon Pack...|   4.7|
# |              Wallpapers HD, 4K...|   4.7|
# |              FUN Keyboard – Em...|   4.7|
# |              All-In-One Toolbo...|   4.7|
# |              Calculator - unit...|   4.7|
# |                  Content Transfer|   4.7|
# |              Loop - Habit Tracker|   4.7|
# |              Favorite children...|   4.7|
# |                 Mozart Baby Sleep|   4.7|
# |              Family Album Mite...|   4.7|
# |              Listen to the sto...|   4.7|
# |              Daniel Tiger for ...|   4.7|
# |              weather - weather...|   4.7|
# |              Video Editor,Crop...|   4.7|
# |              Topbuzz: Breaking...|   4.7|
# |              Breaking News, Lo...|   4.7|
# |                      The Guardian|   4.7|
# |              Sygic Car Navigation|   4.7|
# |              Trucker Path – Tr...|   4.7|
# |                             Bible|   4.7|
# |              C4droid - C/C++ c...|   4.7|
# |                C Offline Tutorial|   4.7|
# |                    All C Programs|   4.7|
# |              Clean Master- Spa...|   4.7|
# |              Community by C Space|   4.7|
# |              Learn Basic C - F...|   4.7|
# |              Mobile Security &...|   4.7|
# |                        Solitaire!|   4.7|
# |              Fame Boom for Rea...|   4.7|
# |                   Zombie Catchers|   4.7|
# |                   Harris J Lyrics|   4.7|
# |              2048 BTS J Hope K...|   4.7|
# |              BTS J-Hope Wallpa...|   4.7|
# |              Fuzzy Numbers: Pr...|   4.7|
# |              Korean Dungeon: K...|   4.7|
# |              Fantastic Chefs: ...|   4.7|
# |              Rock N' Cash Casi...|   4.7|
# |              Q Alerts: QAnon D...|   4.7|
# |                  Q Mobile Banking|   4.7|
# |              Join R, Community...|   4.7|
# |                      Neon-R (Red)|   4.7|
# |              Topbuzz: Breaking...|   4.7|
# |                  I Can't Wake Up!|   4.7|
# |                            /u/app|   4.7|
# |               V Bucks ProTips New|   4.7|
# |              Get Free V-bucks_...|   4.7|
# |                   V BTS Wallpaper|   4.7|
# |                    DRAGON QUEST V|   4.7|
# |              B & W Filter for ...|   4.7|
# |              X Launcher: With ...|   4.7|
# |              X Launcher Pro: P...|   4.7|
# |                    iSwipe Phone X|   4.7|
# |              X Launcher Prime:...|   4.7|
# |                 Anime X Wallpaper|   4.7|
# |              NEW Theme for Pho...|   4.7|
# |                       Z Champions|   4.7|
# |              Ultimate Ab & Cor...|   4.7|
# |                 Angry Birds Match|   4.7|
# |              Ab Workouts - Ab ...|   4.7|
# |                 AC Troubleshooter|   4.7|
# |              Ez Screen Recorde...|   4.7|
# |              Best Applock - Lo...|   4.7|
# |              Ae Allah na Dai (...|   4.7|
# |              Event Manager - A...|   4.7|
# |              Nasihat - Chalo a...|   4.7|
# |                           AF Link|   4.7|
# |              Hesab.af - Send m...|   4.7|
# |                          Bazar.af|   4.7|
# |               All States Ag Parts|   4.7|
# |                  Safe Ag Systems™|   4.7|
# |                 ai robot keyboard|   4.7|
# |              Jamaa Amino for A...|   4.7|
# |              Alabama Gameday Live|   4.7|
# |                       Al-Muhaffiz|   4.7|
# |              Al Quran Audio (F...|   4.7|
# |                   Ayat - Al Quran|   4.7|
# |                       Al Mayadeen|   4.7|
# |              Al Quran MP3 - Qu...|   4.7|
# |              Al'Quran Bahasa I...|   4.7|
# |              Hafizi Quran 15 l...|   4.7|
# |              Al-Quran Ahmad Sa...|   4.7|
# |              12 Step Meditatio...|   4.7|
# |                 Quran for Android|   4.7|
# |              Al Quran Free - ا...|   4.7|
# |                   Surah Al-Waqiah|   4.7|
# |              Muslim Pro - Pray...|   4.7|
# |              DWWW 774 Ultimate...|   4.7|
# |              AO Surgery Reference|   4.7|
# |                  Attack the Light|   4.7|
# |              Bubbu – My Virtua...|   4.7|
# |                             UniFi|   4.7|
# |              AP Government Review|   4.7|
# |              ap,wifi testing,i...|   4.7|
# |              AP Chemistry Prep...|   4.7|
# |              500 AP World Hist...|   4.7|
# |              AP European Histo...|   4.7|
# |              Guess the Class ?...|   4.7|
# |              Grow Stone Online...|   4.7|
# |                         Egg, Inc.|   4.7|
# |              Five Nights at Fl...|   4.7|
# |              Five Nights at Fr...|   4.7|
# |              Australia Newspap...|   4.7|
# |              Neuvaine au Saint...|   4.7|
# |              Kaspersky Mobile ...|   4.7|
# |                      HCP Anywhere|   4.7|
# |                   Anime Expo 2018|   4.7|
# |                     Axe Wallpaper|   4.7|
# |              Movie Downloader ...|   4.7|
# |                     Arizona Trail|   4.7|
# |                          Goody.ba|   4.7|
# |              Elifba Quran Lear...|   4.7|
# |                        BC's Pizza|   4.7|
# |              Baby Connect (act...|   4.7|
# |                  BD Bank Interest|   4.7|
# |                     BD Hospital's|   4.7|
# |                        Bowmasters|   4.7|
# |              BG LINKED (BGLINKED)|   4.7|
# |              Learn Bulgarian Free|   4.7|
# |              ALL-IN-ONE PACKAG...|   4.7|
# |                       BusyBox Pro|   4.7|
# |              Zoho Reports - Mo...|   4.7|
# |              Bingo Party - Fre...|   4.7|
# |              Cards Casino:Vide...|   4.7|
# |                           BJ Toys|   4.7|
# |              BlackJack -21 Cas...|   4.7|
# |              Audio Murli Gloss...|   4.7|
# |              BK Traffic Contro...|   4.7|
# |                 BK Shivani Videos|   4.7|
# |          あなカレ【BL】無料ゲーム|   4.7|
# |                   BL!TZ - Endless|   4.7|
# |              BeyondMenu Food D...|   4.7|
# |              Basket Manager 20...|   4.7|
# |              NOOK App for NOOK...|   4.7|
# |              Browsery by Barne...|   4.7|
# |                   Bo's School Day|   4.7|
# |              Blood Pressure Lo...|   4.7|
# |                BQ-መጽሐፍ ቅዱሳዊ ጥያቄዎች|   4.7|
# |              B R Telco FCU Mob...|   4.7|
# |              Dr B R Ambedkar (...|   4.7|
# |                       BT Share It|   4.7|
# |              Battery Notifier ...|   4.7|
# |              BU Students' Rep....|   4.7|
# |                         SA HLA BU|   4.7|
# |                    My Budget Book|   4.7|
# |                         BW-Joseki|   4.7|
# |              Bx Thailand Alert...|   4.7|
# |              BX Mobile TMC for...|   4.7|
# |              Crypto Tracker by...|   4.7|
# |              CoinMarketApp - C...|   4.7|
# |              Quadratic Equatio...|   4.7|
# |              Color by Number –...|   4.7|
# |              Sandbox - Color b...|   4.7|
# |              Sandbox Art-Sandb...|   4.7|
# |              Color By Number -...|   4.7|
# |              Draw Color by Num...|   4.7|
# |              Bingo by IGG: Top...|   4.7|
# |              UNICORN - Color B...|   4.7|
# |              Voxel - 3D Color ...|   4.7|
# |                       BZ Reminder|   4.7|
# |                   BZ Conferencing|   4.7|
# |                         CB Trader|   4.7|
# |              Football-CB GO Cl...|   4.7|
# |              Pregnancy Tracker...|   4.7|
# |              Cystic Fibrosis S...|   4.7|
# |                           Casa CF|   4.7|
# |                 All Info about Cg|   4.7|
# |                     CG Freelancer|   4.7|
# |              BF CG Abstract Pi...|   4.7|
# |              Ultimate Public C...|   4.7|
# |              boattheory.ch Ful...|   4.7|
# |                    Battery HD Pro|   4.7|
# |                   DRAGON QUEST IV|   4.7|
# |              Automagic * Autom...|   4.7|
# |              FlashLight HD LED...|   4.7|
# |              CI Screwed - Icon...|   4.7|
# |                      CJ Camcorder|   4.7|
# |                      Credit Karma|   4.7|
# |              Calvin Klein – US...|   4.7|
# |                          Louis CK|   4.7|
# |              CK Multimedia - G...|   4.7|
# |              Fu*** Weather (Fu...|   4.7|
# |                   CL-Phlebotomist|   4.7|
# |                            CL-App|   4.7|
# |              Security Master -...|   4.7|
# |              CM Launcher 3D Pro💎|   4.7|
# |              Speed Booster - R...|   4.7|
# |              Swift Dark CM / C...|   4.7|
# |              Melior NUI - Mate...|   4.7|
# |              Length Converter:...|   4.7|
# |              Cartoon Network M...|   4.7|
# |              We Bare Bears Mat...|   4.7|
# |              Them Bombs: co-op...|   4.7|
# |              Central Bank and ...|   4.7|
# |                 Holl & Co Barbers|   4.7|
# |              Poke Genie - Safe...|   4.7|
# |                    Sabbath School|   4.7|
# |                    ClanManagerTT2|   4.7|
# |                            theCut|   4.7|
# |              Ultimate Clash Ro...|   4.7|
# |                     CA CS Network|   4.7|
# |               CT Scan Generations|   4.7|
# |              Solar CT PV Syste...|   4.7|
# |              Service CU Mobile...|   4.7|
# |              BayPort CU Mobile...|   4.7|
# |              Meritrust CU Mobi...|   4.7|
# |                  Cx File Explorer|   4.7|
# |              Theme For Techno ...|   4.7|
# |                          Cytus II|   4.7|
# |              Cy-Fair FCU Mobil...|   4.7|
# |                             Cytus|   4.7|
# |                     Alpha Bank CY|   4.7|
# |                    CY Digital Net|   4.7|
# |              Face Filter, Self...|   4.7|
# |                The Zueira's Voice|   4.7|
# |                       Sound Meter|   4.7|
# |              Driver Permit Tes...|   4.7|
# |              Anime Love Story ...|   4.7|
# |                     Digital Falak|   4.7|
# |                 Krazy Coupon Lady|   4.7|
# |                   Daily Horoscope|   4.7|
# |                       Idle Heroes|   4.7|
# |               Deck Heroes: Legacy|   4.7|
# |              Duolingo: Learn L...|   4.7|
# |              Fancy Pants Adven...|   4.7|
# |              Quik – Free Video...|   4.7|
# |              Advanced Download...|   4.7|
# |              TorrDroid - Torre...|   4.7|
# |                          Daily DM|   4.7|
# |              Day Night Live Wa...|   4.7|
# |              CritDice - Dice R...|   4.7|
# |                    Darkness Rises|   4.7|
# |                        To Do List|   4.7|
# |              Memory Helper - T...|   4.7|
# |                        that's lit|   4.7|
# |              Profile pictures ...|   4.7|
# |              DP and Status Ima...|   4.7|
# |              Instant DP Downlo...|   4.7|
# |              Latest DP and Sta...|   4.7|
# |                   Dr. Seuss's ABC|   4.7|
# |              Riptide GP: Renegade|   4.7|
# |              WhatsVPN - Unlimi...|   4.7|
# |              Weather Forecast Pro|   4.7|
# |              DU Collage Maker ...|   4.7|
# |                  Clean My Android|   4.7|
# |             GO Security－AntiV...|   4.7|
# |              DW فارسی By dw-ar...|   4.7|
# |                   News: RFI Hausa|   4.7|
# |              Retro City Rampag...|   4.7|
# |              Dz Dinars Numbers...|   4.7|
# |              CCP DZ : Fill out...|   4.7|
# |              IRIS : Customer S...|   4.7|
# |                        infirmiers|   4.7|
# |               Exército Brasileiro|   4.7|
# |              Walk Freely (Ec S...|   4.7|
# |              GATE Syllabus for...|   4.7|
# |                     EF Calculator|   4.7|
# |                    EGW Writings 2|   4.7|
# |                      EGW Writings|   4.7|
# |              Bible with EGW Co...|   4.7|
# |              SDA Sabbath Schoo...|   4.7|
# |                            EI国际|   4.7|
# |                 Learn Music Notes|   4.7|
# |                           ek tuhi|   4.7|
# |              Toilet Ek Prem Ka...|   4.7|
# |                   The Holy Rosary|   4.7|
# |               Narcos: Cartel Wars|   4.7|
# |              Learn Top 300 Eng...|   4.7|
# |                        The EO Bar|   4.7|
# |                 Where's My Water?|   4.7|
# |               EP Research Service|   4.7|
# |              Super Doctor 2 - ...|   4.7|
# |              Open Heart Surger...|   4.7|
# |              ES File Explorer/...|   4.7|
# |              ES Disk Analyzer ...|   4.7|
# |                       ES Anywhere|   4.7|
# |              Advanced calculat...|   4.7|
# |              ET Telecom from E...|   4.7|
# |              Learn Italian wit...|   4.7|
# |              Offline Maps & Na...|   4.7|
# |                             CVRIA|   4.7|
# |              VAT Checker for E...|   4.7|
# |                         PlugShare|   4.7|
# |              Beard Live Camera...|   4.7|
# |               An Elite Warrior Ex|   4.7|
# |              EY India Tax Insi...|   4.7|
# |              EY India CFO Insi...|   4.7|
# |              Fuel Calculator f...|   4.7|
# |                Pink Guy - Ey B0ss|   4.7|
# |              Ey Sey Storytime ...|   4.7|
# |              EZ-GUI Ground Sta...|   4.7|
# |              Profile Tracker -...|   4.7|
# |                   FB Photographie|   4.7|
# |              FC Barcelona Offi...|   4.7|
# |               Deportivo Toluca FC|   4.7|
# |              FD Community FCU ...|   4.7|
# |              EMI, FD, RD - Ban...|   4.7|
# |                         SCI-FI UI|   4.7|
# |              FJ Final Join , C...|   4.7|
# |              Permit Test FL Fl...|   4.7|
# |              Charlotte County, FL|   4.7|
# ...
# |                   fred's Pharmacy|   3.0|
# |                      Delta Dental|   3.0|
# |                         Dexcom G6|   3.0|
# |                       Exposure Ed|   3.0|
# |                   fred's Pharmacy|   3.0|
# |              VZ Navigator for ...|   3.0|
# |              Google app for An...|   3.0|
# |                          G-SHOCK+|   3.0|
# |                 G-SHOCK Connected|   3.0|
# |               Ohio State Fair 4-H|   3.0|
# |                     Android P 9.0|   3.0|
# |                   T-Mobile DIGITS|   3.0|
# |                DIRECTV Remote App|   3.0|
# |              Octo U: Your driv...|   3.0|
# |                           U Guard|   3.0|
# |                  AC Remote For LG|   3.0|
# |              Universal AC Remo...|   3.0|
# |               The Ah Yeah! Button|   3.0|
# |              The Artificial In...|   3.0|
# |              AI Draw | Art Fil...|   3.0|
# |              Shoot M-16 vs AK-...|   3.0|
# |              eChallan Andhra P...|   3.0|
# |                    Paint Space AR|   3.0|
# |              EML UPnP-AV Contr...|   3.0|
# |                       Axe Spinner|   3.0|
# |                     Q7 SmartWatch|   3.0|
# |                    BC Lotto Check|   3.0|
# |              BF Browser by Bet...|   3.0|
# |              Cordova BG Geoloc...|   3.0|
# |                  BH Bikes Premium|   3.0|
# |              Lezhin Comics - D...|   3.0|
# |                       BN Mi Banco|   3.0|
# |              BPme - Mobile Fue...|   3.0|
# |                        BQ Scanner|   3.0|
# |                                BR|   3.0|
# |                Best Western To Go|   3.0|
# |                           BW Taxi|   3.0|
# |              Rized ‼️ Color By...|   3.0|
# |              California Cop As...|   3.0|
# |                  Disc Label Print|   3.0|
# |                                ci|   3.0|
# |                      CI On The Go|   3.0|
# |              MYCU TX Mobile Ba...|   3.0|
# |                             My CW|   3.0|
# |                        CW Deposit|   3.0|
# |                             CX-40|   3.0|
# |                             LC-DB|   3.0|
# |                        Penny Puss|   3.0|
# |              Go Go Coupons - F...|   3.0|
# |              Coupon Mob - Disc...|   3.0|
# |                            DH UFO|   3.0|
# |                             DN.VR|   3.0|
# |                      DT Fieldlink|   3.0|
# |                           DV KING|   3.0|
# |                        Dy So Exam|   3.0|
# |                         edp re:dy|   3.0|
# |                       EC-HRV test|   3.0|
# |                   EF Spelling Bee|   3.0|
# |              EG Classroom Deci...|   3.0|
# |                            TAMAGO|   3.0|
# |                        Tamago egg|   3.0|
# |                       Egg for Pou|   3.0|
# |              Ek Kahani Aisi Bh...|   3.0|
# |              2019 Tricks Es Fi...|   3.0|
# |              ESLock File Recov...|   3.0|
# |                      Going Abroad|   3.0|
# |              Qserve EU MDR Fir...|   3.0|
# |              Emerge EV App (eB...|   3.0|
# |              Bolt - EV Chargin...|   3.0|
# |                          EdiRange|   3.0|
# |                           EZ View|   3.0|
# |                         FE Mobile|   3.0|
# |                            FE CPS|   3.0|
# |              Lennox iComfort W...|   3.0|
# |                FarmersOnly Dating|   3.0|
# |              Sugar Daddies Dat...|   2.9|
# |                 Dialysis of Drugs|   2.9|
# |                   NBC Sports Gold|   2.9|
# |                            B.GOOD|   2.9|
# |                             HPlus|   2.9|
# |                        H Band 2.0|   2.9|
# |                          Fossil Q|   2.9|
# |              [verify-U] VideoI...|   2.9|
# |                        PLAYBULB X|   2.9|
# |                    WoW AH Tracker|   2.9|
# |               I am extremely Rich|   2.9|
# |                 3D Holograms Joke|   2.9|
# |                        AP Planner|   2.9|
# |                  iScore5 AP Psych|   2.9|
# |                         Jenga® AR|   2.9|
# |              Advanced Warfare ...|   2.9|
# |                 Outdoor Movies BC|   2.9|
# |                 Talking Boyfriend|   2.9|
# |                     BH by Kinomap|   2.9|
# |                SkyTest BU/GU Lite|   2.9|
# |              BlitzWolf Shutter...|   2.9|
# |              bitcoin exchange ...|   2.9|
# |              Test de Inteligen...|   2.9|
# |              REI Co-op Mastercard|   2.9|
# |                    Sprig by CO-OP|   2.9|
# |                           MYTO CZ|   2.9|
# |                       DrivingTest|   2.9|
# |                      DM Me - Chat|   2.9|
# |                          DN eAvis|   2.9|
# |                  DV Lottery Photo|   2.9|
# |                Wifi Action Camera|   2.9|
# |               DENVER ACTION CAM 3|   2.9|
# |                           EF-myHR|   2.9|
# |              Education First F...|   2.9|
# |              EG SIM CARD (EGSI...|   2.9|
# |                               Egg|   2.9|
# |              Advanced EX for M...|   2.9|
# |              Advanced EX for N...|   2.9|
# |                        EZ Display|   2.9|
# |              EZ-Placard - Free...|   2.9|
# |                        Safe Wi-Fi|   2.9|
# |                                fi|   2.9|
# |              Employ Florida Mo...|   2.9|
# |              SB · FN 1870 Mobi...|   2.9|
# |              FreedomPop Diagno...|   2.9|
# |                Adult Dirty Emojis|   2.8|
# |                Adult Dirty Emojis|   2.8|
# |                Adult Dirty Emojis|   2.8|
# |              Brilliant Distinc...|   2.8|
# |                    Patient Portal|   2.8|
# |                     How Old am I?|   2.8|
# |                             Z App|   2.8|
# |              Trane Interactive...|   2.8|
# |              AF Comics Reader ...|   2.8|
# |               Club Penguin Island|   2.8|
# |                 AJ Bell Youinvest|   2.8|
# |              Baby Game Animal ...|   2.8|
# |              Sleep as Android ...|   2.8|
# |                   BringGo AU & NZ|   2.8|
# |              Free Coupons for ...|   2.8|
# |                        Bullshite!|   2.8|
# |              Bt Notifier -Smar...|   2.8|
# |                              B.T.|   2.8|
# |                            BW App|   2.8|
# |              bz Basellandschaf...|   2.8|
# |                          CF SHOP!|   2.8|
# |              Gold Teeth Photo ...|   2.8|
# |                   Company Kitchen|   2.8|
# |                       New: CL-150|   2.8|
# |                            KFC CZ|   2.8|
# |              Roland DG Mobile ...|   2.8|
# |              DK 15 Minute Lang...|   2.8|
# |              NY mobilbank DK -...|   2.8|
# |                        DM airdisk|   2.8|
# |                         DM HiDisk|   2.8|
# |              Interactive NPC D...|   2.8|
# |                  Discovery Insure|   2.8|
# |                         Selfie DV|   2.8|
# |                          Porch DV|   2.8|
# |                      My EF Center|   2.8|
# |                        EV Connect|   2.8|
# |                      HondaLink EV|   2.8|
# |              Advanced EX for R...|   2.8|
# |                    EZ Inspections|   2.8|
# |                            EZ-SEE|   2.8|
# |                 My EZ-Link Mobile|   2.8|
# |              FE Civil Engineer...|   2.8|
# |                       MouseMingle|   2.7|
# |                       MouseMingle|   2.7|
# |                   Anthem Anywhere|   2.7|
# |                   Anthem Anywhere|   2.7|
# |                     How Do I Look|   2.7|
# |              The Q - Live Triv...|   2.7|
# |              X-ray scanner sim...|   2.7|
# |                            ClanHQ|   2.7|
# |                          Rugby AU|   2.7|
# |               Ai-Ball AV Recorder|   2.7|
# |                    AirWatch Inbox|   2.7|
# |                HTC Sense Input-BG|   2.7|
# |                     MagicLight BT|   2.7|
# |                   Color by Disney|   2.7|
# |              Truck Chat & CB f...|   2.7|
# |                     CK Pharmacies|   2.7|
# |                          CL Clock|   2.7|
# |                         CQ Mobile|   2.7|
# |                       DB LINK RGB|   2.7|
# |              Bilingual Diction...|   2.7|
# |                         DW Mobile|   2.7|
# |              EURES - Your Job ...|   2.7|
# |              Advanced EX for H...|   2.7|
# |                      EY GlobalOne|   2.7|
# |              Fisher-Price® Sma...|   2.7|
# |                        Calculator|   2.6|
# |              InfantRisk Center...|   2.6|
# |                Anthem BC Anywhere|   2.6|
# |                   Fossil Q Legacy|   2.6|
# |                  TOSHIBA Smart AC|   2.6|
# |                  Brandon Lakes AH|   2.6|
# |              Turbo AI™ - Perso...|   2.6|
# |              Sleep as Android ...|   2.6|
# |                Anthem BC Anywhere|   2.6|
# |              Body Scanner xray...|   2.6|
# |                          BG Score|   2.6|
# |                        FitConsole|   2.6|
# |                         My BP Lab|   2.6|
# |                      CG Fit Scale|   2.6|
# |              Car Search For Cr...|   2.6|
# |                          Leica CL|   2.6|
# |              Bomb and Nade Tim...|   2.6|
# |                       CT Prepares|   2.6|
# |              Curriculum Vitae ...|   2.6|
# |                           DG Cars|   2.6|
# |                 Svenska Dagbladet|   2.6|
# |                  DS Connector 2.0|   2.6|
# |                     Break the Egg|   2.6|
# |                         EO Global|   2.6|
# |                        FH WiFiCam|   2.6|
# |              EliteSingles – Da...|   2.5|
# |              Sugar Daddy Datin...|   2.5|
# |              EliteSingles – Da...|   2.5|
# |                          VeinSeek|   2.5|
# |                 mobileRx Pharmacy|   2.5|
# |              Remote For ATT U-...|   2.5|
# |                      W Box VMS HD|   2.5|
# |              Carrier Air Condi...|   2.5|
# |                 Avios for Android|   2.5|
# |                       BT Notifier|   2.5|
# |                               QST|   2.5|
# |                           DH News|   2.5|
# |                      DM EVOLUTION|   2.5|
# |                    Dagens Nyheter|   2.5|
# |                         SportLook|   2.5|
# |                           EA Plus|   2.5|
# |              TNEB Bill Checker...|   2.5|
# |                         EY Events|   2.5|
# |                           EZ Pass|   2.5|
# |                          My Truck|   2.5|
# |                   Pint - FN Theme|   2.5|
# |              Libre Scan (Diabe...|   2.4|
# |              DRC Sim - Wii U G...|   2.4|
# |                     Wi u Emulator|   2.4|
# |              Remote Control Fo...|   2.4|
# |                 PS4 Second Screen|   2.4|
# |              BA Pro Financial ...|   2.4|
# |              Virtual Boyfriend...|   2.4|
# |              CSCS BG (в българ...|   2.4|
# |                      Run on Earth|   2.4|
# |                  Bullshit! (Free)|   2.4|
# |                CA Case Management|   2.4|
# |                        CJ Fitness|   2.4|
# |                      DB Event App|   2.4|
# |               Aster DM Healthcare|   2.4|
# |                           DT NO.I|   2.4|
# |                          AKASO DV|   2.4|
# |                WiFi Action Camera|   2.4|
# |                         EG Retail|   2.4|
# |                     EI SmartMiles|   2.4|
# |              5 Minute Veterina...|   2.3|
# |                     J - Style Pro|   2.3|
# |                      Ag PhD Soils|   2.3|
# |              App Seguridad AV ...|   2.3|
# |                          BC Pizza|   2.3|
# |                      Bg TV Online|   2.3|
# |                 BJ's Express Scan|   2.3|
# |                Bono’s Pit Bar-B-Q|   2.3|
# |              Benefit Extras Mo...|   2.3|
# |              Webmail web mobil...|   2.3|
# |                         CR Family|   2.3|
# |              What's Your CS:GO...|   2.3|
# |                     CV-RECORD Pro|   2.3|
# |              DK Eyewitness Aud...|   2.3|
# |                         DQ Events|   2.3|
# |                        DV KING 4K|   2.3|
# |              EF Go Ahead Tour ...|   2.3|
# |                     EP Lab Digest|   2.3|
# |              NissanConnect® EV...|   2.3|
# |              Remote EX for NISSAN|   2.3|
# |              Air Transat CineP...|   2.2|
# |                        Q-See Plus|   2.2|
# |                     Moto Z Market|   2.2|
# |                       Hi-Smart AC|   2.2|
# |              BF Scale Health F...|   2.2|
# |              BG Remover & Eras...|   2.2|
# |              Hungry Girl Diet ...|   2.2|
# |                    Feel Performer|   2.2|
# |                     bz Basel News|   2.2|
# |                         Thrive CF|   2.2|
# |                The CW TN app 2018|   2.2|
# |                   CZ File Manager|   2.2|
# |              e-DN - den digita...|   2.2|
# |                            EZ LED|   2.2|
# |                 AZ REMOTE CONTROL|   2.1|
# |                            BA4You|   2.1|
# |                        BP Toolbox|   2.1|
# |                     DG Smart life|   2.1|
# |                         Sports DV|   2.1|
# |              EZ-ELD Driver App...|   2.1|
# |              First Hawaiian Ba...|   2.1|
# |                   Candy simply-Fi|   2.1|
# |              Bridge-C - Get Mo...|   2.0|
# |                          AF Hydro|   2.0|
# |               AppFinder by AppTap|   2.0|
# |                       UM BP Track|   2.0|
# |              Bell and Wyson Ca...|   2.0|
# |                   CF Appreciation|   2.0|
# |              SharedCare™ Co-pa...|   2.0|
# |                         Travis CU|   2.0|
# |              Public Service CU...|   2.0|
# |                           Live DV|   2.0|
# |              VMAX IP Plus Mobi...|   2.0|
# |              Check Lottery Tic...|   2.0|
# |              Just She - Top Le...|   1.9|
# |              Just She - Top Le...|   1.9|
# |              Just She - Top Le...|   1.9|
# |                         W Box VMS|   1.9|
# |                  Kenmore Smart AC|   1.9|
# |                 ESS Mobile for AE|   1.9|
# |                Loreal - BA Makeup|   1.9|
# |                      Yuzu eReader|   1.9|
# |                       BR Chat Bot|   1.9|
# |              CJ Fallon eBook R...|   1.9|
# |                        Co Checker|   1.9|
# |                      DB Transport|   1.9|
# |                         TAXLANDIA|   1.9|
# |                       G-Playlists|   1.8|
# |              Q-Tech Companion App|   1.8|
# |              Smart-AC Universa...|   1.8|
# |                       Wireless BP|   1.8|
# |              bp Magazine for B...|   1.8|
# |              Boston University...|   1.8|
# |                         DS-20000S|   1.8|
# |                Furrion ES Control|   1.8|
# |                           C by GE|   1.7|
# |              A/C REFRIGERANT C...|   1.7|
# |                   A&W Restaurants|   1.7|
# |                         BG TV App|   1.7|
# |              Bitcoin BX Thaila...|   1.7|
# |                             CW TV|   1.7|
# |                       DT Baby Cam|   1.7|
# |                         EB Mobile|   1.7|
# |              AC REMOTE UNIVERS...|   1.6|
# |                      Pick-a-Paint|   1.6|
# |                 Co-op Connections|   1.6|
# |                          DT Smart|   1.6|
# |                  CB Mobile Access|   1.5|
# |                          CF Climb|   1.5|
# |                       FK Atlantas|   1.5|
# |                   BD Provider App|   1.4|
# |                Hercules CP Mobile|   1.4|
# |                           Quiz DC|   1.4|
# |                        EY TaxChat|   1.2|
# |              House party - liv...|   1.0|
# |                 Speech Therapy: F|   1.0|
# |                     Clarksburg AH|   1.0|
# |              Truck Driving Tes...|   1.0|
# |              BJ Bridge Standar...|   1.0|
# |                            MbH BM|   1.0|
# |                     CB Mobile Biz|   1.0|
# |                    Thistletown CI|   1.0|
# |                    CJ DVD Rentals|   1.0|
# |                       CR Magazine|   1.0|
# |              Tech CU Card Manager|   1.0|
# |                    DS Creator 2.0|   1.0|
# |                    DT future1 cam|   1.0|
# |              FE Mechanical Eng...|   1.0|
# |              Familial Hypercho...|   1.0|
# |              Lottery Ticket Ch...|   1.0|
# +----------------------------------+------+

# %% [markdown]
# <h4>5.6. Number of apps in each Genre</h4>

# %%
spark.sql('''
SELECT Genres, COUNT(*) as TotalApps
FROM apps
GROUP BY Genres
ORDER BY TotalApps DESC
''').show(10)
# Out:
# +-------------+---------+
# |       Genres|TotalApps|
# +-------------+---------+
# |        Tools|      733|
# |Entertainment|      533|
# |    Education|      468|
# |       Action|      358|
# | Productivity|      351|
# |      Medical|      350|
# |       Sports|      333|
# |Communication|      328|
# |      Finance|      323|
# |  Photography|      317|
# +-------------+---------+
# only showing top 10 rows

# %% [markdown]
# <h4>5.7. Top Categories by Average Rating</h4>

# %%
spark.sql('''
SELECT Category, AVG(Rating) as AvgRating
FROM apps
GROUP BY Category
ORDER BY AvgRating DESC
''').show()
# Out:
# +-------------------+------------------+
# |           Category|         AvgRating|
# +-------------------+------------------+
# |             EVENTS| 4.435555555555557|
# |          EDUCATION| 4.389032258064517|
# |     ART_AND_DESIGN| 4.358064516129031|
# |BOOKS_AND_REFERENCE| 4.346067415730338|
# |    PERSONALIZATION| 4.335987261146501|
# |          PARENTING| 4.300000000000001|
# |               GAME|4.2863263445761195|
# |             BEAUTY| 4.278571428571428|
# | HEALTH_AND_FITNESS|4.2771043771043775|
# |           SHOPPING| 4.259663865546221|
# |             SOCIAL| 4.255598455598457|
# |            WEATHER| 4.243999999999999|
# |             SPORTS| 4.223510971786835|
# |       PRODUCTIVITY| 4.211396011396012|
# |     HOUSE_AND_HOME| 4.197368421052633|
# |             FAMILY| 4.192272467086437|
# |        PHOTOGRAPHY| 4.192113564668767|
# |  AUTO_AND_VEHICLES|  4.19041095890411|
# |            MEDICAL|  4.18914285714286|
# | LIBRARIES_AND_DEMO| 4.178461538461538|
# +-------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# <h4>5.8. Price Distribution of Paid Apps</h4>

# %%
spark.sql('''
SELECT Price, COUNT(*) as count
FROM apps
WHERE Type='Paid'
GROUP BY Price
ORDER BY CAST(Price AS FLOAT) DESC
''').show(10)
# Out:
# +-----+-----+
# |Price|count|
# +-----+-----+
# |  400|    1|
# |  399|   11|
# |  389|    1|
# |  379|    1|
# |  299|    1|
# |   79|    2|
# |   39|    1|
# |   37|    1|
# |   33|    2|
# |   29|    6|
# +-----+-----+
# only showing top 10 rows

# %% [markdown]
# <h4>5.9. Average Rating By Price Range</h4>

# %%
spark.sql('''
    SELECT 
        CASE 
            WHEN Price = '0' THEN 'Free' 
            WHEN Price BETWEEN '1' AND '50' THEN '1-50$'
            WHEN Price BETWEEN '51' AND '100' THEN '51-100$'
            WHEN Price BETWEEN '101' AND '200' THEN '101-200$'
            WHEN Price BETWEEN '201' AND '300' THEN '201-300$'
            WHEN Price BETWEEN '301' AND '400' THEN '301-400$'
            WHEN Price >= 401 THEN 'Above 400$'
        END AS PriceRange,
        AVG(Rating) AS AvgRating
    FROM apps
    GROUP BY PriceRange
    ORDER BY PriceRange
''').show()
# Out:
# +----------+-----------------+
# |PriceRange|        AvgRating|
# +----------+-----------------+
# |     1-50$| 4.27036328871893|
# |  201-300$|              3.8|
# |  301-400$|3.871428571428571|
# |   51-100$|              4.6|
# |      Free|4.187559483344679|
# +----------+-----------------+

# %% [markdown]
# <h4>5.10. Average Rating of Paid vs Free Apps</h4>

# %%
spark.sql('''
SELECT Type, AVG(Rating) as AvgRating
FROM apps
GROUP BY Type
''').show()
# Out:
# +----+-----------------+
# |Type|        AvgRating|
# +----+-----------------+
# |Free|4.186202546163562|
# |Paid|4.266615146831529|
# +----+-----------------+
